# %%
import numpy as np
import functions_Oscillate
import importlib
importlib.reload(functions_Oscillate)
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
#plotting options
blue = sns.color_palette()[0]
red = sns.color_palette()[1]
green = sns.color_palette()[2]
yellow = sns.color_palette()[4]

# Seed for reproduceability
np.random.seed(1234)

# %%
Beta = np.array([1.1, 0.9, 1])
n = 2
# r0 = (2 / (n-2)) ** (1/n)
alpha = 216
# alpha = r0 ** (n+1) + r0
alpha_0 = alpha / 1000


par = alpha, alpha_0, Beta, n

# %%
importlib.reload(functions_Oscillate)
datasets = 50
steps = 1
t_step = 50
t_points = 1000

m1, m2, m3, P1, P2, P3, mult, t, t_mult = functions_Oscillate.ODE_int(datasets, steps, t_step, t_points, par)

# %%
# m1 = m1[:,1:,:]
# m2 = m2[:,1:,:]
# m3 = m3[:,1:,:]
# P1 = P1[:,1:,:]
# P2 = P2[:,1:,:]
# P3 = P3[:,1:,:]
# mult = mult[:,1:,:]
# t = t[:,1:,:]
# t_mult = t_mult[:,1:,:]

# %%
mult_mean = (10 - 0) / 2
mult_std = (10 - 0) / np.sqrt(12)

m1_mean = np.mean(np.log(m1[:-1,:,:]))
m1_std = np.std(np.log(m1[:-1,:,:]))
m2_mean = np.mean(np.log(m2[:-1,:,:]))
m2_std = np.std(np.log(m2[:-1,:,:]))
m3_mean = np.mean(np.log(m3[:-1,:,:]))
m3_std = np.std(np.log(m3[:-1,:,:]))
P1_mean = np.mean(np.log(P1[:-1,:,:]))
P1_std = np.std(np.log(P1[:-1,:,:]))
P2_mean = np.mean(np.log(P2[:-1,:,:]))
P2_std = np.std(np.log(P2[:-1,:,:]))
P3_mean = np.mean(np.log(P3[:-1,:,:]))
P3_std = np.std(np.log(P3[:-1,:,:]))

# m1_mean = np.mean(m1[:-1,:,:])
# m1_std = np.std(m1[:-1,:,:])
# m2_mean = np.mean(m2[:-1,:,:])
# m2_std = np.std(m2[:-1,:,:])
# m3_mean = np.mean(m3[:-1,:,:])
# m3_std = np.std(m3[:-1,:,:])
# P1_mean = np.mean(P1[:-1,:,:])
# P1_std = np.std(P1[:-1,:,:])
# P2_mean = np.mean(P2[:-1,:,:])
# P2_std = np.std(P2[:-1,:,:])
# P3_mean = np.mean(P3[:-1,:,:])
# P3_std = np.std(P3[:-1,:,:])


m1_norm = (np.log(m1) - m1_mean) / m1_std
m2_norm = (np.log(m2) - m2_mean) / m2_std
m3_norm = (np.log(m3) - m3_mean) / m3_std
P1_norm = (np.log(P1) - P1_mean) / P1_std
P2_norm = (np.log(P2) - P2_mean) / P2_std
P3_norm = (np.log(P3) - P3_mean) / P3_std
mult_norm = np.log(mult) 

# m1_norm = (m1 - m1_mean) / m1_std
# m2_norm = (m2 - m2_mean) / m2_std
# m3_norm = (m3 - m3_mean) / m3_std
# P1_norm = (P1 - P1_mean) / P1_std
# P2_norm = (P2 - P2_mean) / P2_std
# P3_norm = (P3 - P3_mean) / P3_std

# %%
print(m1.shape)
# Out:
# (51, 1, 1000)

# %%
index = 0
skip = 0
# skip = 0

# t_plot = t[index,:,skip:].flatten()
# t_mult_plot = t_mult[index,:,skip:].flatten()
# m1_plot = m1[index,:,skip:].flatten()
# m2_plot = m2[index,:,skip:].flatten()
# m3_plot = m3[index,:,skip:].flatten()
# P1_plot = P1[index,:,skip:].flatten()
# P2_plot = P2[index,:,skip:].flatten()
# P3_plot = P3[index,:,skip:].flatten()
# mult_plot = mult[index,:,skip:].flatten()
# 
# m1_norm_plot = m1_norm[index,:,skip:].flatten()
# m2_norm_plot = m2_norm[index,:,skip:].flatten()
# m3_norm_plot = m3_norm[index,:,skip:].flatten()
# P1_norm_plot = P1_norm[index,:,skip:].flatten()
# P2_norm_plot = P2_norm[index,:,skip:].flatten()
# P3_norm_plot = P3_norm[index,:,skip:].flatten()
# mult_norm_plot = mult[index,:,skip:].flatten()

t_plot = t[:,:,skip:].flatten()
t_mult_plot = t_mult[:,:,skip:].flatten()
m1_plot = m1[:,:,skip:].flatten()
m2_plot = m2[:,:,skip:].flatten()
m3_plot = m3[:,:,skip:].flatten()
P1_plot = P1[:,:,skip:].flatten()
P2_plot = P2[:,:,skip:].flatten()
P3_plot = P3[:,:,skip:].flatten()
mult_plot = mult[:,:,skip:].flatten()

m1_norm_plot = m1_norm[:,:,skip:].flatten()
m2_norm_plot = m2_norm[:,:,skip:].flatten()
m3_norm_plot = m3_norm[:,:,skip:].flatten()
P1_norm_plot = P1_norm[:,:,skip:].flatten()
P2_norm_plot = P2_norm[:,:,skip:].flatten()
P3_norm_plot = P3_norm[:,:,skip:].flatten()
mult_norm_plot = mult[:,:,skip:].flatten()

ax1 = plt.figure()
plt.plot(t_plot, m1_plot, c=blue, label = 'm1')
plt.plot(t_plot, m2_plot, c=red, label='m2')
plt.plot(t_plot, m3_plot, c=green, label='m3')
plt.ylabel('m1, m2, m3')
plt.legend()

ax2 = plt.figure()
plt.plot(t_plot, P1_plot, c=blue, label = 'P1')
plt.plot(t_plot, P2_plot, c=red, label='P2')
plt.plot(t_plot, P3_plot, c=green, label='P3')
plt.ylabel('P1, P2, P3')
plt.legend()

ax3 = plt.figure()
plt.scatter(P1_plot, P2_plot, c=blue, label = 'P2 vs P1')
plt.ylabel('P1')
plt.legend()

ax4 = plt.figure()
plt.scatter(P1_plot, P3_plot, c=red, label = 'P3 vs P1')
plt.ylabel('P1')
plt.legend()

ax5 = plt.figure()
plt.scatter(m1_plot, m2_plot, c=blue, label = 'm2 vs m1')
plt.ylabel('m1')
plt.legend()

ax6 = plt.figure()
plt.scatter(m1_plot, m3_plot, c=red, label = 'm3 vs m1')
plt.ylabel('m1')
plt.legend()

ax7 = plt.figure()
plt.scatter(P1_norm_plot, P2_norm_plot, c=blue, label = 'P2_norm vs P1_norm')
plt.ylabel('P1')
plt.legend()

ax8 = plt.figure()
plt.scatter(P1_norm_plot, P3_norm_plot, c=red, label = 'P3_norm vs P1_norm')
plt.ylabel('P1')
plt.legend()

ax9 = plt.figure()
plt.scatter(m1_norm_plot, m2_norm_plot, c=blue, label = 'm2_norm vs m1_norm')
plt.ylabel('m1')
plt.legend()

ax10 = plt.figure()
plt.scatter(m1_norm_plot, m3_norm_plot, c=red, label = 'm3_norm vs m1_norm')
plt.ylabel('m1')
plt.legend()

fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(nrows=7, sharex=True, figsize=(8,8))
plt.suptitle('Unnormalized Data')
ax1.plot(t_plot, m1_plot, c=blue)
ax1.set_ylabel('m1')

ax2.plot(t_plot, m2_plot, c=blue)
ax2.set_ylabel('m2')

ax3.plot(t_plot, m3_plot, c=blue)
ax3.set_ylabel('m3')

ax4.plot(t_plot, P1_plot, c=blue)
ax4.set_ylabel('P1')

ax5.plot(t_plot, P2_plot, c=blue)
ax5.set_ylabel('P2')

ax6.plot(t_plot, P3_plot, c=blue)
ax6.set_ylabel('P3')

ax7.semilogy(t_mult_plot, mult_plot, c=green)
ax7.set_ylabel('mult')

plt.xlabel('Time [min]')

fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9) = plt.subplots(nrows=9, sharex=True, sharey=False, figsize=(8,8))
plt.suptitle('Normalized Data')
ax1.plot(t_plot, m1_norm_plot, c=blue, label = 'A')
ax1.plot(t_plot, m2_norm_plot, c=red, label='B')
ax1.plot(t_plot, m3_norm_plot, c=green, label='C')
ax1.set_ylabel('A, B, C')
ax1.legend()

ax2.plot(t_plot, P1_norm_plot, c=blue, label = 'P1')
ax2.plot(t_plot, P2_norm_plot, c=red, label='P2')
ax2.plot(t_plot, P3_norm_plot, c=green, label='P3')
ax2.set_ylabel('P1, P2, P3')
ax2.legend()

ax3.plot(t_plot, m1_norm_plot, c=blue)
ax3.set_ylabel('m1')

ax4.plot(t_plot, m2_norm_plot, c=blue)
ax4.set_ylabel('m2')

ax5.plot(t_plot, m3_norm_plot, c=blue)
ax5.set_ylabel('m3')

ax6.plot(t_plot, P1_norm_plot, c=blue)
ax6.set_ylabel('P1')

ax7.plot(t_plot, P2_norm_plot, c=blue)
ax7.set_ylabel('P2')

ax8.plot(t_plot, P3_norm_plot, c=blue)
ax8.set_ylabel('P3')

ax9.semilogy(t_mult_plot, mult_norm_plot, c=green)
ax9.set_ylabel('mult')

plt.xlabel('Time [min]')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
print(np.min([2,4]))
# Out:
# 2

# %%
skip = 0

h = t[:,:,1:] - t[:,:,:-1] 
t1 = t[:,:,:].reshape((datasets + 1,-1))
h = t1[:,1:] - t1[:,:-1] 

train_in = np.array([m1_norm[:,:,:].reshape((datasets+1,-1))[:-1,:-1].flatten(),
                    m2_norm[:,:,:].reshape((datasets+1,-1))[:-1,:-1].flatten(),
                    m3_norm[:,:,:].reshape((datasets+1,-1))[:-1,:-1].flatten(),
                    P1_norm[:,:,:].reshape((datasets+1,-1))[:-1,:-1].flatten(),
                    P2_norm[:,:,:].reshape((datasets+1,-1))[:-1,:-1].flatten(),
                    P3_norm[:,:,:].reshape((datasets+1,-1))[:-1,:-1].flatten(),
                    mult_norm[:,:,:].reshape((datasets+1,-1))[:-1,:-1].flatten(),
                    h[:-1,:].flatten()]).transpose()

print(mult_norm[:-1,:,:].flatten().shape)
print(datasets)
print(t[:,1:,:].reshape((11,-1)).shape)
print(h[:-1,:].flatten().shape)
print(h.shape)
print(mult_norm[:-1,1:,:].flatten()[:-1].shape)
print(h[:-1,:].flatten().shape)
print(train_in.shape)

# train_in = np.array([m1_norm[:-1,:,skip:-1].flatten(),
#                     m2_norm[:-1,:,skip:-1].flatten(),
#                     m3_norm[:-1,:,skip:-1].flatten(),
#                     P1_norm[:-1,:,skip:-1].flatten(),
#                     P2_norm[:-1,:,skip:-1].flatten(),
#                     P3_norm[:-1,:,skip:-1].flatten(),
#                     mult_norm[:-1,:,skip:-1].flatten()]).transpose()

train_pred = np.array([m1_norm[:,:,:].reshape((datasets+1,-1))[:-1,1:].flatten(),
                    m2_norm[:,:,:].reshape((datasets+1,-1))[:-1,1:].flatten(),
                    m3_norm[:,:,:].reshape((datasets+1,-1))[:-1,1:].flatten(),
                    P1_norm[:,:,:].reshape((datasets+1,-1))[:-1,1:].flatten(),
                    P2_norm[:,:,:].reshape((datasets+1,-1))[:-1,1:].flatten(),
                    P3_norm[:,:,:].reshape((datasets+1,-1))[:-1,1:].flatten()
                       ]).transpose()

print(train_pred.shape)

test = np.array([m1_norm[-1,:,:].flatten(),
                m2_norm[-1,:,:].flatten(),
                m3_norm[-1,:,:].flatten(),
                P1_norm[-1,:,:].flatten(),
                P2_norm[-1,:,:].flatten(),
                P3_norm[-1,:,:].flatten(),
                mult_norm[-1,:,:].flatten(),
                h[-1,:].flatten()]).transpose()

# test = np.array([m1_norm[-1,:,:].flatten(),
#                 m2_norm[-1,:,:].flatten(),
#                 m3_norm[-1,:,:].flatten(),
#                 P1_norm[-1,:,:].flatten(),
#                 P2_norm[-1,:,:].flatten(),
#                 P3_norm[-1,:,:].flatten(),
#                 mult_norm[-1,:,:].flatten()]).transpose()
# Out:
# (50000,)
# 50
# (11, 0)
# (49950,)
# (51, 999)
# (0,)
# (49950,)
# (49950, 8)
# (49950, 6)

# %%
print(train_in.shape)
# Out:
# (49950, 8)

# %%
importlib.reload(functions_Oscillate)

HL = 3
HL_Nodes = 10
Activation = 'softplus'
learning_rate_pred = 1e-3 # default is 1e-3
print(train_in.shape)
RK4_model = functions_Oscillate.RK4_Integrator_Model(HL_Nodes, Activation, learning_rate_pred)
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate_pred)
RK4_model.build(train_in.shape)
RK4_model.compile(optimizer=optimizer,
              loss='mse',       # mean squared error
              metrics=['mae'])  # mean absolute error
RK4_model.summary()
# Out:
# (49950, 8)
# Model: "r_k4__integrator__model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              multiple                  80
# _________________________________________________________________
# dense_9 (Dense)              multiple                  110
# _________________________________________________________________
# dense_10 (Dense)             multiple                  110
# _________________________________________________________________
# dense_11 (Dense)             multiple                  66
# ...
# Total params: 366
# Trainable params: 366
# Non-trainable params: 0
# _________________________________________________________________

# %%
# import tensorflow as tf
# from tensorflow.keras import layers
# 
# HL = 5
# HL_Nodes = 20
# Activation = 'softplus'
# learning_rate_pred = 1e-3 # default is 1e-3
# 
# model = tf.keras.Sequential()
# model.add(layers.Dense(HL_Nodes, activation=Activation, input_shape=(7,)))
# for i in range(HL - 1):
#     model.add(layers.Dense(HL_Nodes, activation=Activation,))
# model.add(layers.Dense(6, activation='linear'))
# 
# # Configure a model for mean-squared error regression.
# optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate_pred)
# model.compile(optimizer=optimizer,
#               loss='mse',       # mean squared error
#               metrics=['mae'])  # mean absolute error
# model.summary()

# %%
import kerasUtils
importlib.reload(kerasUtils)

Pbar = kerasUtils.Pbar
batch_size = 5000
Epoch_Num = 10000
history = RK4_model.fit(train_in,train_pred,
                          batch_size=batch_size,
                          epochs=Epoch_Num, validation_split=0.1, verbose=False, shuffle=True, 
                          callbacks=[Pbar(Epoch_Num)]
                         )

plt.plot(np.log(history.history['loss']), label='training data')
plt.plot(np.log(history.history['val_loss']), label='validation data')
plt.ylabel('value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()
# Out:
# ...
# Training: 100%|██████████| 10000/10000 [46:56<00:00,  3.42Epoch/s]

# %%
import tensorflow as tf
from tqdm import tqdm_notebook as tqdm
index = -1

test = np.array([m1_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    m2_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    m3_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    P1_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    P2_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    P3_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    mult_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    h[index,:].flatten()]).transpose()
print(test.shape)
pred_offline = np.zeros(np.shape(test))
pred_offline[0,:] = test[0,:]
pred_offline[:,-2:] = test[:,-2:]

pbar = tqdm(total=np.shape(test)[0] - 1)

for i in range(np.shape(test)[0] - 1 - skip):
    pbar.update()
    input = pred_offline[i,:].reshape(1,-1)
    output = RK4_model.predict(input)
    pred_offline[i+1,:-2] = output

# test = np.array([m1_norm[index,:,:-1].flatten(),
#                 m2_norm[index,:,:-1].flatten(),
#                 m3_norm[index,:,:-1].flatten(),
#                 P1_norm[index,:,:-1].flatten(),
#                 P2_norm[index,:,:-1].flatten(),
#                 P3_norm[index,:,:-1].flatten(),
#                 mult_norm[index,:,:-1].flatten()]).transpose()
# print(test.shape)
# pred_offline = np.zeros(np.shape(test))
# pred_offline[0:skip+1,:] = test[0:skip+1,:]
# pred_offline[:,-1] = test[:,-1]
# 
# pbar = tqdm(total=np.shape(test)[0] - 1)
# 
# for i in range(np.shape(test)[0] - 1 - skip):
#     pbar.update()
#     input = pred_offline[i+skip,:].reshape(1,-1)
#     output = RK4_model.predict(input)
#     pred_offline[i+1+skip,:-1] = output
# Out:
# (999, 8)
# C:\Users\saura\anaconda3\lib\site-packages\ipykernel_launcher.py:18: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
Error_Offline = np.average((test - pred_offline) ** 2)
print(Error_Offline)
print(test[0,:])
print(pred_offline[0,:])
# Out:
# 0.021158880401543984
# [ 1.25759396  0.58732596 -0.07929808  0.55436023  1.025377    0.78101505
#   2.30258509  0.1       ]
# [ 1.25759396  0.58732596 -0.07929808  0.55436023  1.025377    0.78101505
#   2.30258509  0.1       ]

# %%
t_plot = t[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
m1_plot = m1_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
m2_plot = m2_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
m3_plot = m3_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
P1_plot = P1_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
P2_plot = P2_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
P3_plot = P3_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
mult_plot = mult[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()

m1_pred = pred_offline[:,0]
m2_pred = pred_offline[:,1]
m3_pred = pred_offline[:,2]
P1_pred = pred_offline[:,3]
P2_pred = pred_offline[:,4]
P3_pred = pred_offline[:,5]

plt.figure(0)
plt.scatter(m1_pred, m2_pred, c=red)
plt.scatter(m1_plot, m2_plot, c=blue)

fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(nrows=7, sharex=True, sharey=False, figsize=(8,8))
ax1.plot(t_plot, m1_plot, c=blue)
ax1.plot(t_plot, m1_pred, c=red)

ax2.plot(t_plot, m2_plot, c=blue)
ax2.plot(t_plot, m2_pred, c=red)

ax3.plot(t_plot, m3_plot, c=blue)
ax3.plot(t_plot, m3_pred, c=red)

ax4.plot(t_plot, P1_plot, c=blue)
ax4.plot(t_plot, P1_pred, c=red)

ax5.plot(t_plot, P2_plot, c=blue)
ax5.plot(t_plot, P2_pred, c=red)

ax6.plot(t_plot, P3_plot, c=blue)
ax6.plot(t_plot, P3_pred, c=red)

ax7.plot(t_plot, mult_plot, c=green)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import tensorflow as tf
from tqdm import tqdm_notebook as tqdm
index = -1

test = np.array([m1_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    m2_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    m3_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    P1_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    P2_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    P3_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    mult_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten(),
                    h[index,:].flatten()]).transpose()
print(mult_norm.shape)
print(mult_norm[:,1:,:].reshape((datasets+1,-1)).shape)
print(mult_norm[:,1:,:].reshape((datasets+1,-1))[index,:-1].flatten().shape)
print(h[index,:].flatten().shape)
print(test.shape)
pred_online = np.zeros(np.shape(test))
pred_online[0,:] = test[0,:]
pred_online[:,-2:] = test[:,-2:]

pbar = tqdm(total=np.shape(test)[0] - 1)

for i in range(np.shape(test)[0] - 1 - skip):
    pbar.update()
    input = test[i,:].reshape(1,-1)
    output = RK4_model.predict(input)
    pred_online[i+1,:-2] = output

# test = np.array([m1_norm[index,:,:-1].flatten(),
#                 m2_norm[index,:,:-1].flatten(),
#                 m3_norm[index,:,:-1].flatten(),
#                 P1_norm[index,:,:-1].flatten(),
#                 P2_norm[index,:,:-1].flatten(),
#                 P3_norm[index,:,:-1].flatten(),
#                 mult_norm[index,:,:-1].flatten()]).transpose()
# print(test.shape)
# pred_offline = np.zeros(np.shape(test))
# pred_offline[0:skip+1,:] = test[0:skip+1,:]
# pred_offline[:,-1] = test[:,-1]
# 
# pbar = tqdm(total=np.shape(test)[0] - 1)
# 
# for i in range(np.shape(test)[0] - 1 - skip):
#     pbar.update()
#     input = pred_offline[i+skip,:].reshape(1,-1)
#     output = RK4_model.predict(input)
#     pred_offline[i+1+skip,:-1] = output
# Out:
# (51, 1, 1000)
# (51, 0)
# (0,)
# (999,)
# (999, 8)
# C:\Users\saura\anaconda3\lib\site-packages\ipykernel_launcher.py:22: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
Error_Online = np.average((test - pred_online) ** 2)
print(Error_Online)
# Out:
# 6.384301197793682e-07

# %%
t_plot = t[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
m1_plot = m1_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
m2_plot = m2_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
m3_plot = m3_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
P1_plot = P1_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
P2_plot = P2_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
P3_plot = P3_norm[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()
mult_plot = mult[:,:,:].reshape((datasets+1,-1))[index,:-1].flatten()

m1_pred = pred_online[:,0]
m2_pred = pred_online[:,1]
m3_pred = pred_online[:,2]
P1_pred = pred_online[:,3]
P2_pred = pred_online[:,4]
P3_pred = pred_online[:,5]

plt.figure(0)
plt.scatter(m1_pred, m2_pred, c=red)
plt.scatter(m1_plot, m2_plot, c=blue)

fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(nrows=7, sharex=True, sharey=False, figsize=(8,8))
ax1.plot(t_plot, m1_plot, c=blue)
ax1.plot(t_plot, m1_pred, c=red)

ax2.plot(t_plot, m2_plot, c=blue)
ax2.plot(t_plot, m2_pred, c=red)

ax3.plot(t_plot, m3_plot, c=blue)
ax3.plot(t_plot, m3_pred, c=red)

ax4.plot(t_plot, P1_plot, c=blue)
ax4.plot(t_plot, P1_pred, c=red)

ax5.plot(t_plot, P2_plot, c=blue)
ax5.plot(t_plot, P2_pred, c=red)

ax6.plot(t_plot, P3_plot, c=blue)
ax6.plot(t_plot, P3_pred, c=red)

ax7.plot(t_plot, mult_plot, c=green)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
ANN1 = RK4_model.ANN1
ANN2 = RK4_model.ANN2
ANN3 = RK4_model.ANN3
ANNout = RK4_model.ANNout

# def myANN_ODE(t, inputs):
#     output = ANNout(
#                 ANN1(
#                 ANN2(
#                 ANN3(inputs))))
#     return output

inputs = tf.keras.Input(shape=(7,))
x = ANN3(inputs)
x = ANN2(x)
x = ANN1(x)
outputs = ANNout(x)

odeModel = tf.keras.Model(inputs=inputs, outputs=outputs)

def myANN_ODE(t, inputs, E0):
    argument = np.append(inputs, E0).reshape((1,7))
    output = odeModel.predict(argument)
    return output.reshape(6)

# %%
datasets = 1
steps = 1
t_step = 100
t_points = 1000

m1_difftest, m2_difftest, m3_difftest, P1_difftest, P2_difftest, P3_difftest\
    , mult_difftest, t_difftest, t_mult_difftest \
    = functions_Oscillate.ODE_int(datasets, steps, t_step, t_points, par)

m1_norm_difftest = (np.log(m1_difftest) - m1_mean) / m1_std
m2_norm_difftest = (np.log(m2_difftest) - m2_mean) / m2_std
m3_norm_difftest = (np.log(m3_difftest) - m3_mean) / m3_std
P1_norm_difftest = (np.log(P1_difftest) - P1_mean) / P1_std
P2_norm_difftest = (np.log(P2_difftest) - P2_mean) / P2_std
P3_norm_difftest = (np.log(P3_difftest) - P3_mean) / P3_std
mult_norm_difftest = np.log(mult_difftest) 

# steps = 10
# E0_arr = np.zeros((steps))
# E0_mean = (0.01 - 0) / 2
# E0_std = (0.01 - 0) / np.sqrt(12)

# for i in range(steps):
#     E0_arr[i] = (np.random.uniform(0, 0.01) - E0_mean) / E0_std
mult_norm_flat = mult_norm_difftest[-1,:,:].flatten()
indexes = np.unique(mult_norm_flat, return_index=True)[1]
mult_arr = [mult_norm_flat[index] for index in sorted(indexes)]

# %%
importlib.reload(functions_Oscillate)
from scipy.integrate import solve_ivp

m1_init = m1_norm_difftest[-1,0,0]
m2_init = m2_norm_difftest[-1,0,0]
m3_init = m3_norm_difftest[-1,0,0]
P1_init = P1_norm_difftest[-1,0,0]
P2_init = P2_norm_difftest[-1,0,0]
P3_init = P3_norm_difftest[-1,0,0]

init = np.array([m1_init, m2_init, m3_init, P1_init, P2_init, P3_init])

# t_points = 5

t_ode = np.zeros((steps, t_points))
m1_ode = np.zeros((steps, t_points))
m2_ode = np.zeros((steps, t_points))
m3_ode = np.zeros((steps, t_points))
P1_ode = np.zeros((steps, t_points))
P2_ode = np.zeros((steps, t_points))
P3_ode = np.zeros((steps, t_points))
t_mult_ode = np.zeros((steps, t_points))
mult_plot_ode = np.zeros((steps, t_points))



for j in range(np.int(steps)):
    t_start = t_difftest[-1,j,0]
    my_Mult = 10
    t_end = t_difftest[-1,j,-1]
    t_span = np.linspace(t_start, t_end, t_points, endpoint=True)
    t_max_step = t_span[1] - t_span[0]
    mult_ode = np.zeros(t_span.shape) + my_Mult
    # mult = [1]
    print(t_mult_ode.shape)
    print(t_span.shape)
    t_mult_ode[j,:] = t_span
    mult_plot_ode[j,:] = mult_ode

    sol = solve_ivp(myANN_ODE, [t_start, t_end], init, t_eval=t_span, args=[np.log(mult_ode[0])], max_step = t_max_step / 5, method='BDF')
    t1_ode = sol.t
    m11_ode, m21_ode, m31_ode, P11_ode, P21_ode, P31_ode = sol.y

    t_ode[j,:] = t1_ode
    m1_ode[j,:] = m11_ode
    m2_ode[j,:] = m21_ode
    m3_ode[j, :] = m31_ode
    P1_ode[j, :] = P11_ode
    P2_ode[j, :] = P21_ode
    P3_ode[j, :] = P31_ode

    # t_end += t_step
    init = [m11_ode[-1], m21_ode[-1], m31_ode[-1], P11_ode[-1], P21_ode[-1], P31_ode[-1]]
# Out:
# (1, 1000)
# (1000,)

# %%
print(t_ode.shape)
print(m1_ode.shape)

print([m1_ode[0,0], m2_ode[0,0], m3_ode[0,0]])
print([m1_norm_difftest[-1,0,0], m2_norm_difftest[-1,0,0], m3_norm_difftest[-1,0,0]])

print([P1_ode[0,0], P2_ode[0,0], P3_ode[0,0]])
print([P1_norm_difftest[-1,0,0], P2_norm_difftest[-1,0,0], P3_norm_difftest[-1,0,0]])
# Out:
# (1, 1000)
# (1, 1000)
# [1.3687175804090719, 1.7118214706932917, 1.1897129898842131]
# [1.3687175804090719, 1.7118214706932917, 1.1897129898842131]
# [1.1604137946753674, 1.8595291261985767, 1.9380350921559457]
# [1.1604137946753674, 1.8595291261985767, 1.9380350921559457]

# %%
t_plot = t_difftest[-1,:,:].flatten()
m1_plot = m1_norm_difftest[-1,:,:].flatten()
m2_plot = m2_norm_difftest[-1,:,:].flatten()
m3_plot = m3_norm_difftest[-1,:,:].flatten()
P1_plot = P1_norm_difftest[-1,:,:].flatten()
P2_plot = P2_norm_difftest[-1,:,:].flatten()
P3_plot = P3_norm_difftest[-1,:,:].flatten()
mult_plot = mult_difftest[-1,:,:].flatten()

t_plot_ode = t_ode.flatten()
m1_pred = m1_ode.flatten()
m2_pred = m2_ode.flatten()
m3_pred = m3_ode.flatten()
P1_pred = P1_ode.flatten()
P2_pred = P2_ode.flatten()
P3_pred = P3_ode.flatten()

plt.figure(0)
plt.scatter(m1_pred, m2_pred, c=red)
plt.scatter(m1_plot, m2_plot, c=blue)

fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(nrows=7, sharex=True, sharey=False, figsize=(8,8))
ax1.plot(t_plot, m1_plot, c=blue)
ax1.plot(t_plot_ode, m1_pred, c=red)

ax2.plot(t_plot, m2_plot, c=blue)
ax2.plot(t_plot_ode, m2_pred, c=red)

ax3.plot(t_plot, m3_plot, c=blue)
ax3.plot(t_plot_ode, m3_pred, c=red)

ax4.plot(t_plot, P1_plot, c=blue)
ax4.plot(t_plot_ode, P1_pred, c=red)

ax5.plot(t_plot, P2_plot, c=blue)
ax5.plot(t_plot_ode, P2_pred, c=red)

ax6.plot(t_plot, P3_plot, c=blue)
ax6.plot(t_plot_ode, P3_pred, c=red)

ax7.plot(t_plot, mult_plot, c=green)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
